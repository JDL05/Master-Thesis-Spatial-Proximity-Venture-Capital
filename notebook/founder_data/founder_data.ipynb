# %% [markdown]
# # Founder Data Scraping

# %% [markdown]
# ## Project Description

# %% [markdown]
# **What is this about?**
#
# - Right now, I only have fundamental information about companies and their treatment of the seed round. But Venture Capital investors evaluate more than that and many early stage investors would agrue that the founding team is the most important argument why they invested. As we already have interesting Venture Capital categories in combination with the success, it would be interesting to know if the different investor types have certain investment tendencies according to the teams.
#
# **What tools are used?**
#
# - We use two tools to get the founder data. The first tool, Serper API, helps to get the linkedin profiles. The API is a google search api and with the correct command, the link of the founder can be extracted. The second tool is Phantombuster. Phantombuster is a multicase scraping engine and I will use it to use the linkedin profile urls to scrape the profile data. As we have around 19k companies with around 33k founders, this may take a while to respect the LinkedIn usage rules.
#
# **How is it done?**
#
# - First of all, all founders are stored in a data frame together with the company name. This will result in a 33k-row data frame. Then, a new column is created that stores the request body which is a combination of the name, the startup name and an additional element that indicates that we are looking for a linkedin profile. As the API only has 2.5k free tokens, another 47.5k tokens will be purchased. The created data frame now has the linkedin profiles. To prevent misled results, I will integrate a quality check step and filter out all rows with a missing url. Then, we export the data frame and import it to the phantom buster platform. In batches of 1.5k per day, the data is scraped and stored. After finalization, the data can be downloaded and used for further cleaning and engineering.

# %% [markdown]
# ## Data Import and Preparation

# %%
import pandas as pd
import os
from dotenv import load_dotenv
import requests
import json

os.chdir('/Users/janlinzner/Projects/Master-Thesis-Spatial-Proximity-Venture-Capital')

# %%
companies = pd.read_csv('data/sets-for-r/companies_seed.csv')

# %%
filtered_companies = companies[companies['Founders'].notna()]
founders_df = filtered_companies.assign(Founders=filtered_companies['Founders'].str.split(', ')).explode('Founders')
founders_df['Founder ID'] = (founders_df.reset_index().index + 1).astype(str).str.zfill(5)
result_df = founders_df[['Company ID', 'Organization Name', 'Organization Name URL', 'Founder ID', 'Founders', 'Success', 'Headquarters Country']]
result_df.rename(columns={'Founders': 'Founder Name'}, inplace=True)
# Out:
# /var/folders/n8/ynbdx9r10lv6l8yh1m_hmbsh0000gn/T/ipykernel_16625/2702257160.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df.rename(columns={'Founders': 'Founder Name'}, inplace=True)

# %%
result_df['Search Query'] = 'site:linkedin.com/in ' + ' ' + result_df['Organization Name'] + ' ' + result_df['Founder Name']
# Out:
# /var/folders/n8/ynbdx9r10lv6l8yh1m_hmbsh0000gn/T/ipykernel_16625/23336708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['Search Query'] = 'site:linkedin.com/in ' + ' ' + result_df['Organization Name'] + ' ' + result_df['Founder Name']

# %%
success_df = result_df[result_df['Success']]
no_success_df = result_df[~result_df['Success']]

# %%
germany_df = result_df[result_df['Headquarters Country'] == 'Germany']

# %%
germany_df
# Out:
#        Company ID          Organization Name  \
# 5            9243                HAPILA GmbH
# 11           9017          InterNations GmbH
# 11           9017          InterNations GmbH
# 24           9480                   Pharetis
# 24           9480                   Pharetis
# ...           ...                        ...
# 16983        9665  heycare (former heynanny)
# 16993        9713                   Kodex AI
# 16993        9713                   Kodex AI
# 17001        9699                     Empion
# 17001        9699                     Empion
#
#                                    Organization Name URL Founder ID  \
# 5      https://www.crunchbase.com/organization/hapila...      00005
# 11     https://www.crunchbase.com/organization/intern...      00015
# 11     https://www.crunchbase.com/organization/intern...      00016
# 24      https://www.crunchbase.com/organization/pharetis      00026
# 24      https://www.crunchbase.com/organization/pharetis      00027
# ...                                                  ...        ...
# 16983  https://www.crunchbase.com/organization/heynan...      30183
# 16993   https://www.crunchbase.com/organization/kodex-ai      30197
# 16993   https://www.crunchbase.com/organization/kodex-ai      30198
# 17001     https://www.crunchbase.com/organization/empion      30207
# 17001     https://www.crunchbase.com/organization/empion      30208
#
#              Founder Name  Success Headquarters Country  \
# 5      Merle Arnika Fuchs    False              Germany
# 11            Malte Zeeck     True              Germany
# 11      Philipp von Plato     True              Germany
# 24           Dirk Ehrlich    False              Germany
# 24         Peter Biermann    False              Germany
# ...                   ...      ...                  ...
# 16983         Julia Kahle    False              Germany
# 16993          Claus Lang    False              Germany
# 16993       Thomas Kaiser    False              Germany
# 17001   Annika von Mutius    False              Germany
# 17001     Larissa Leitner    False              Germany
#
#                                             Search Query
# 5      site:linkedin.com/in  HAPILA GmbH Merle Arnika...
# 11     site:linkedin.com/in  InterNations GmbH Malte ...
# 11     site:linkedin.com/in  InterNations GmbH Philip...
# 24           site:linkedin.com/in  Pharetis Dirk Ehrlich
# 24         site:linkedin.com/in  Pharetis Peter Biermann
# ...                                                  ...
# 16983  site:linkedin.com/in  heycare (former heynanny...
# 16993          site:linkedin.com/in  Kodex AI Claus Lang
# 16993       site:linkedin.com/in  Kodex AI Thomas Kaiser
# 17001     site:linkedin.com/in  Empion Annika von Mutius
# 17001       site:linkedin.com/in  Empion Larissa Leitner
#
# [5158 rows x 8 columns]

# %%
result_df
# Out:
#        Company ID      Organization Name  \
# 0             948  Safetica Technologies
# 3           16735               Quick TV
# 3           16735               Quick TV
# 4           11268      Imperative Energy
# 5            9243            HAPILA GmbH
# ...           ...                    ...
# 16996       18538              PocketEye
# 17000       18550              Combat IQ
# 17000       18550              Combat IQ
# 17001        9699                 Empion
# 17001        9699                 Empion
#
#                                    Organization Name URL Founder ID  \
# 0      https://www.crunchbase.com/organization/safeti...      00001
# 3       https://www.crunchbase.com/organization/quick-tv      00002
# 3       https://www.crunchbase.com/organization/quick-tv      00003
# 4      https://www.crunchbase.com/organization/impera...      00004
# 5      https://www.crunchbase.com/organization/hapila...      00005
# ...                                                  ...        ...
# 16996  https://www.crunchbase.com/organization/pocketeye      30204
# 17000  https://www.crunchbase.com/organization/combat-iq      30205
# 17000  https://www.crunchbase.com/organization/combat-iq      30206
# 17001     https://www.crunchbase.com/organization/empion      30207
# 17001     https://www.crunchbase.com/organization/empion      30208
#
#              Founder Name  Success Headquarters Country  \
# 0            Jakub Mahdal    False       Czech Republic
# 3               Nick Bell    False       United Kingdom
# 3              Tod Yeadon    False       United Kingdom
# 4           Joe O’Carroll    False              Ireland
# 5      Merle Arnika Fuchs    False              Germany
# ...                   ...      ...                  ...
# 16996         Meera Radia    False       United Kingdom
# 17000     Christian Giang    False       United Kingdom
# 17000         Timur Malik    False       United Kingdom
# 17001   Annika von Mutius    False              Germany
# 17001     Larissa Leitner    False              Germany
#
#                                             Search Query
# 0      site:linkedin.com/in  Safetica Technologies Ja...
# 3               site:linkedin.com/in  Quick TV Nick Bell
# 3              site:linkedin.com/in  Quick TV Tod Yeadon
# 4      site:linkedin.com/in  Imperative Energy Joe O’...
# 5      site:linkedin.com/in  HAPILA GmbH Merle Arnika...
# ...                                                  ...
# 16996        site:linkedin.com/in  PocketEye Meera Radia
# 17000    site:linkedin.com/in  Combat IQ Christian Giang
# 17000        site:linkedin.com/in  Combat IQ Timur Malik
# 17001     site:linkedin.com/in  Empion Annika von Mutius
# 17001       site:linkedin.com/in  Empion Larissa Leitner
#
# [30208 rows x 8 columns]

# %% [markdown]
# ## Serper API

# %%
def fetch_linkedin_urls(
    source_df: pd.DataFrame,
    num_to_process: int,
    results_file: str = "founder_linkedin_urls.csv",
    api_key_env_var: str = "serper",
    df_key_columns: tuple = ("Company ID", "Founder ID"),
    query_column: str = "Search Query"
) -> pd.DataFrame:

    source = source_df.copy()
    for key in df_key_columns:
        source[key] = source[key].astype(int)  # e.g. "00001" → 1

    if os.path.exists(results_file):
        existing_results = pd.read_csv(
            results_file,
            dtype={df_key_columns[0]: int, df_key_columns[1]: int}
        )
    else:
        
        cache_columns = list(source.columns) + ["LinkedIn URL"]
        existing_results = pd.DataFrame(columns=cache_columns)
        for key in df_key_columns:
            existing_results[key] = existing_results[key].astype(int)

    merged = pd.merge(
        source,
        existing_results[list(df_key_columns)],  
        how="left",
        on=list(df_key_columns),
        indicator=True
    )
    
    new_rows_mask = merged["_merge"] == "left_only"
    unprocessed = merged.loc[new_rows_mask, source.columns] 

    to_process = unprocessed.head(num_to_process).copy()
    if to_process.empty:
        print("No new rows to process; all keys are already cached.")
        
        return pd.DataFrame(columns=list(source.columns) + ["LinkedIn URL"])

    to_process.reset_index(drop=True, inplace=True)
    to_process["LinkedIn URL"] = None

    SERPER_API_URL = "https://google.serper.dev/search"
    api_key = os.getenv(api_key_env_var)
    if not api_key:
        raise RuntimeError(f"Environment variable '{api_key_env_var}' not set.")
    headers = {"X-API-KEY": api_key}

    for idx, row in to_process.iterrows():
        company_id = int(row[df_key_columns[0]])
        founder_id = int(row[df_key_columns[1]])
        query_text = row[query_column]

        
        cached = existing_results[
            (existing_results[df_key_columns[0]] == company_id) &
            (existing_results[df_key_columns[1]] == founder_id)
        ]
        if not cached.empty:
            url = cached.iloc[0]["LinkedIn URL"]
            print(f"[Row {idx}] (cached) Query: '{query_text}' → URL: {url!r}")
            to_process.at[idx, "LinkedIn URL"] = url
            continue

        print(f"[Row {idx}] (requesting) Query: '{query_text}'")
        payload = {"q": query_text}

        try:
            resp = requests.post(SERPER_API_URL, json=payload, headers=headers)
        except Exception as e:
            print(f"  → Exception on row {idx}: {e}")
            continue

        if resp.status_code == 200:
            data = resp.json().get("organic", [])
            if data:
                first_link = data[0].get("link", "")
                if "linkedin.com/in" in first_link:
                    to_process.at[idx, "LinkedIn URL"] = first_link
                    print(f"  → Found: {first_link!r}")
                else:
                    to_process.at[idx, "LinkedIn URL"] = None
                    print(f"  → Top result not LinkedIn (got {first_link!r}); leaving as None")
            else:
                to_process.at[idx, "LinkedIn URL"] = None
                print("  → No organic results; leaving as None")
        else:
            to_process.at[idx, "LinkedIn URL"] = None
            print(f"  → HTTP {resp.status_code}: {resp.text[:200]!r}… (leaving as None)")


    new_rows_for_cache = to_process.copy() 
    combined = pd.concat([existing_results, new_rows_for_cache], ignore_index=True)

    
    combined.drop_duplicates(subset=list(df_key_columns), keep="first", inplace=True)
    combined.to_csv(results_file, index=False)

    return to_process

# %%
df_new = fetch_linkedin_urls(
     source_df=success_df,
     num_to_process=2000,
     results_file="notebook/founder_data/test_results.csv",
     api_key_env_var="serper",
     df_key_columns=("Company ID", "Founder ID"),
     query_column="Search Query"
)
# Out:
# [Row 0] (requesting) Query: 'site:linkedin.com/in  Sales Layer Iban Borras'
#   → Found: 'https://es.linkedin.com/in/ibanborras'
# [Row 1] (requesting) Query: 'site:linkedin.com/in  Qida Anna Montanes'
#   → No organic results; leaving as None
# [Row 2] (requesting) Query: 'site:linkedin.com/in  Qida Guillem Garcia Galofre'
#   → No organic results; leaving as None
# [Row 3] (requesting) Query: 'site:linkedin.com/in  Qida Lluís Guitart Moya'
#   → Found: 'https://ad.linkedin.com/in/llu%C3%ADs-guitart-moya-986313142'
# [Row 4] (requesting) Query: 'site:linkedin.com/in  Innovamat Andreu Dotti'
#   → Found: 'https://es.linkedin.com/in/andreu-dotti-boada/en'
# [Row 5] (requesting) Query: 'site:linkedin.com/in  Innovamat Isaac Sayol'
#   → Found: 'https://es.linkedin.com/in/isaac-sayol-piedra-8675b2116'
# [Row 6] (requesting) Query: 'site:linkedin.com/in  Innovamat Àlex Pérez-Muelas'
#   → Found: 'https://es.linkedin.com/in/%C3%A0lex-espinet-p%C3%A9rez-muelas-31b97213b'
# [Row 7] (requesting) Query: 'site:linkedin.com/in  ForceManager Oscar Macia'
#   → Found: 'https://es.linkedin.com/in/oscarmacia'
# [Row 8] (requesting) Query: 'site:linkedin.com/in  ForceManager Xavier Bisbal'
#   → Found: 'https://es.linkedin.com/in/xavibisbal'
# [Row 9] (requesting) Query: 'site:linkedin.com/in  Red Points David Casellas'
#   → Found: 'https://es.linkedin.com/in/davidcasellas'
# [Row 10] (requesting) Query: 'site:linkedin.com/in  Red Points Josep Coll Rodriguez'
#   → Found: 'https://es.linkedin.com/in/josep-coll-rodriguez-0b630a23'
# [Row 11] (requesting) Query: 'site:linkedin.com/in  Circular Pedro Torrecillas'
#   → Found: 'https://es.linkedin.com/in/ptorrecillas'
# [Row 12] (requesting) Query: 'site:linkedin.com/in  Circular Teo Ruiz'
#   → Found: 'https://es.linkedin.com/in/teoruiz'
# [Row 13] (requesting) Query: 'site:linkedin.com/in  Amelia Virtual Care Xavier Palomer'
#   → Found: 'https://es.linkedin.com/in/xavierpalomer'
# [Row 14] (requesting) Query: 'site:linkedin.com/in  Heymondo David Pérez Martín'
#   → Found: 'https://es.linkedin.com/in/david-p%C3%A9rez'
# [Row 15] (requesting) Query: 'site:linkedin.com/in  Heymondo Ricard Domenech'
#   → Found: 'https://es.linkedin.com/in/ricard-domenech-pages-972102103'
# [Row 16] (requesting) Query: 'site:linkedin.com/in  Cable Energia Ignacio Lopez Martin'
#   → Found: 'https://es.linkedin.com/in/ignaciolopez1'
# [Row 17] (requesting) Query: 'site:linkedin.com/in  Cable Energia Jesus Nieto Martin'
#   → Found: 'https://es.linkedin.com/in/jesusnietomartin'
# [Row 18] (requesting) Query: 'site:linkedin.com/in  Geoblink Jaime Laulhé'
#   → Found: 'https://es.linkedin.com/in/jaimelaulhe'
# [Row 19] (requesting) Query: 'site:linkedin.com/in  Submer Daniel Pope'
#   → Found: 'https://es.linkedin.com/in/danielpope83'
# [Row 20] (requesting) Query: 'site:linkedin.com/in  Submer Pol Valls Soler'
#   → Found: 'https://es.linkedin.com/in/polvallssoler'
# [Row 21] (requesting) Query: 'site:linkedin.com/in  WOOM Clelia Morales'
#   → Found: 'https://es.linkedin.com/in/cleliamorales'
# [Row 22] (requesting) Query: 'site:linkedin.com/in  WOOM Laurence Fontinoy'
#   → Found: 'https://es.linkedin.com/in/laurencefontinoy'
# [Row 23] (requesting) Query: 'site:linkedin.com/in  Peptomyc Laura Soucek'
#   → Found: 'https://es.linkedin.com/in/laurasoucek'
# [Row 24] (requesting) Query: 'site:linkedin.com/in  Peptomyc Marie-Eve Beaulieu'
#   → Found: 'https://es.linkedin.com/in/marie-eve-beaulieu-27756b13'
# [Row 25] (requesting) Query: 'site:linkedin.com/in  SANIFIT Joan Perelló'
#   → Found: 'https://es.linkedin.com/in/joan-perell%C3%B3-bestard-39909a11'
# [Row 26] (requesting) Query: 'site:linkedin.com/in  Revelock Pablo de la Riva Ferrezuelo'
#   → Found: 'https://es.linkedin.com/in/jorgemartineztaboada/en'
# [Row 27] (requesting) Query: 'site:linkedin.com/in  Declarando Juanjo Traver'
#   → Found: 'https://es.linkedin.com/in/juanjo-traver-radiu-0380a827'
# [Row 28] (requesting) Query: 'site:linkedin.com/in  Declarando Marta Zaragozá Faucón'
#   → No organic results; leaving as None
# [Row 29] (requesting) Query: 'site:linkedin.com/in  Declarando Vicente Solsona'
#   → Found: 'https://es.linkedin.com/in/ardisalvo'
# [Row 30] (requesting) Query: 'site:linkedin.com/in  Nautal Edu Robsy'
#   → Found: 'https://es.linkedin.com/in/edu-robsy'
# [Row 31] (requesting) Query: 'site:linkedin.com/in  Nautal Eduard Llovet'
#   → Found: 'https://es.linkedin.com/in/ellovet'
# [Row 32] (requesting) Query: 'site:linkedin.com/in  Nautal Octavi Uyà'
#   → Found: 'https://es.linkedin.com/in/octaviuya'
# [Row 33] (requesting) Query: 'site:linkedin.com/in  Nautal Roger Hom'
#   → Found: 'https://es.linkedin.com/in/rogerllovethom/en'
# [Row 34] (requesting) Query: 'site:linkedin.com/in  Deporvillage Angel Corcuera'
#   → Found: 'https://es.linkedin.com/in/angelcorcuera'
# [Row 35] (requesting) Query: 'site:linkedin.com/in  Deporvillage Xavier Pladellorens'
#   → Found: 'https://es.linkedin.com/in/xavierpladellorens'
# [Row 36] (requesting) Query: 'site:linkedin.com/in  Finteca Carlos Blanco'
#   → Found: 'https://es.linkedin.com/in/lorena-blanco-torres-938645135'
# [Row 37] (requesting) Query: 'site:linkedin.com/in  Finteca Marc Torres'
#   → Found: 'https://es.linkedin.com/in/marctorres'
# [Row 38] (requesting) Query: 'site:linkedin.com/in  Finteca Silvia Escamez Romero'
#   → Found: 'https://es.linkedin.com/in/silvia-escamez/en?trk=public_post_main-feed-card-text'
# [Row 39] (requesting) Query: 'site:linkedin.com/in  Gudog James McElroy'
#   → Found: 'https://uk.linkedin.com/in/james-mcelroy-964a3196'
# [Row 40] (requesting) Query: 'site:linkedin.com/in  Gudog Javier Cuevas'
#   → Found: 'https://es.linkedin.com/in/javiercr'
# [Row 41] (requesting) Query: 'site:linkedin.com/in  Gudog Loly Garrido'
#   → Found: 'https://es.linkedin.com/in/lolygarrido'
# [Row 42] (requesting) Query: 'site:linkedin.com/in  Gudog Timothy McElroy'
#   → Found: 'https://ie.linkedin.com/in/timothymc'
# [Row 43] (requesting) Query: 'site:linkedin.com/in  Agroptima Anisia Tarda'
#   → Found: 'https://es.linkedin.com/in/anisiatarda'
# [Row 44] (requesting) Query: 'site:linkedin.com/in  Agroptima Emilia Vila'
#   → Found: 'https://es.linkedin.com/in/emiliavila'
# [Row 45] (requesting) Query: 'site:linkedin.com/in  Agroptima Ferran Gascon Burgada'
#   → Found: 'https://es.linkedin.com/in/ferrangascon'
# [Row 46] (requesting) Query: 'site:linkedin.com/in  Arengu Jacobo Vidal Abeigón'
#   → Found: 'https://es.linkedin.com/in/jacobovidal/en'
# [Row 47] (requesting) Query: 'site:linkedin.com/in  Arengu Pablo Castro'
#   → Found: 'https://es.linkedin.com/in/pablocastrovalino'
# [Row 48] (requesting) Query: 'site:linkedin.com/in  Tiko Ana Villanueva'
#   → Found: 'https://ph.linkedin.com/in/lhoed-villanueva-527905283'
# [Row 49] (requesting) Query: 'site:linkedin.com/in  Tiko Can Günay'
#   → Found: 'https://www.linkedin.com/in/gunay-garaeva'
# [Row 50] (requesting) Query: 'site:linkedin.com/in  Tiko Paco Cebrian'
#   → Found: 'https://es.linkedin.com/in/pacosahuquillo/en'
# [Row 51] (requesting) Query: 'site:linkedin.com/in  Tiko Sina Afra'
#   → Found: 'https://tr.linkedin.com/in/sinaafra'
# [Row 52] (requesting) Query: 'site:linkedin.com/in  Rebellion Pay Sergio Cerro'
#   → Found: 'https://es.linkedin.com/in/sergiocerro'
# [Row 53] (requesting) Query: 'site:linkedin.com/in  Spacewell Energy (Dexma) Guillem Corominas'
#   → Found: 'https://es.linkedin.com/in/guillemcorominas'
# [Row 54] (requesting) Query: 'site:linkedin.com/in  Spacewell Energy (Dexma) Joan Pinyol Blasi'
#   → Found: 'https://es.linkedin.com/in/joanpinyol'
# [Row 55] (requesting) Query: 'site:linkedin.com/in  Spacewell Energy (Dexma) Xavier Orduña'
#   → Found: 'https://es.linkedin.com/in/galdric-ruiz-08a70851'
# [Row 56] (requesting) Query: 'site:linkedin.com/in  Worldcoo Aureli Bou'
#   → Found: 'https://es.linkedin.com/in/aurelibou'
# [Row 57] (requesting) Query: 'site:linkedin.com/in  Worldcoo Sergi Figueres Moret'
#   → Found: 'https://es.linkedin.com/in/sergifigueres'
# [Row 58] (requesting) Query: 'site:linkedin.com/in  Aplazame Daniel Molina'
#   → Found: 'https://ae.linkedin.com/in/dani-molina'
# [Row 59] (requesting) Query: 'site:linkedin.com/in  Aplazame Fernando Cabello-Astolfi'
#   → Found: 'https://es.linkedin.com/in/fcabelloastolfi/es'
# [Row 60] (requesting) Query: 'site:linkedin.com/in  Aplazame François Derbaix'
#   → Found: 'https://es.linkedin.com/in/nachoormeno/es?trk=public_post_reshare-text'
# [Row 61] (requesting) Query: 'site:linkedin.com/in  Travel Compositor Manuel Aragonés'
#   → Found: 'https://es.linkedin.com/in/manuel-aragones-4a583246/en'
# [Row 62] (requesting) Query: 'site:linkedin.com/in  Travel Compositor Vicente Rossello'
#   → Found: 'https://es.linkedin.com/in/vicente-rossell%C3%B3-jaume-741a04a'
# [Row 63] (requesting) Query: 'site:linkedin.com/in  Holded Bernat Ripoll'
#   → Found: 'https://es.linkedin.com/in/ripollbernat'
# [Row 64] (requesting) Query: 'site:linkedin.com/in  Holded Javi Fondevila'
#   → Found: 'https://es.linkedin.com/in/javifondevila'
# [Row 65] (requesting) Query: 'site:linkedin.com/in  Gestoos Andrea Halfpap'
#   → Found: 'https://es.linkedin.com/in/andrea-halfpap'
# [Row 66] (requesting) Query: 'site:linkedin.com/in  Gestoos Germán León'
#   → Found: 'https://es.linkedin.com/in/germandleono'
# [Row 67] (requesting) Query: 'site:linkedin.com/in  Gestoos Marcel Alcoverro'
#   → Found: 'https://es.linkedin.com/in/marcelalcoverro'
# [Row 68] (requesting) Query: 'site:linkedin.com/in  Camelina Company España Borja Alonso de Linaje Pérez'
#   → Found: 'https://es.linkedin.com/in/borjaalonsodelinaje'
# [Row 69] (requesting) Query: 'site:linkedin.com/in  Camelina Company España Yuri Herreras Yambanis'
#   → Found: 'https://br.linkedin.com/in/yuri-herreras-yambanis-337592b6'
# [Row 70] (requesting) Query: 'site:linkedin.com/in  Pridatect Borja Fernández'
#   → Found: 'https://www.linkedin.com/in/diazdeteran/'
# [Row 71] (requesting) Query: 'site:linkedin.com/in  Pridatect David Casellas'
#   → Found: 'https://es.linkedin.com/in/davidcasellas'
# [Row 72] (requesting) Query: 'site:linkedin.com/in  Pridatect Lluís Alsina'
#   → Found: 'https://www.linkedin.com/in/frank-artacho'
# [Row 73] (requesting) Query: 'site:linkedin.com/in  Pridatect Pedro Simón Castellano'
#   → No organic results; leaving as None
# [Row 74] (requesting) Query: 'site:linkedin.com/in  Captio Dan Moser'
#   → Found: 'https://es.linkedin.com/in/danmoserfuste/en'
# [Row 75] (requesting) Query: 'site:linkedin.com/in  Captio Joaquim Segura'
#   → Found: 'https://es.linkedin.com/in/joaquim-segura-ca%C3%B1ada-88b71610'
# [Row 76] (requesting) Query: 'site:linkedin.com/in  Captio Joel Vicient'
#   → Found: 'https://es.linkedin.com/in/jvicient'
# [Row 77] (requesting) Query: 'site:linkedin.com/in  Captio Lluis Font'
#   → Found: 'https://www.linkedin.com/in/luis-antonio-ramirez-ba6014b6'
# [Row 78] (requesting) Query: 'site:linkedin.com/in  Captio Lluís Claramonte'
#   → Found: 'https://es.linkedin.com/in/lluis-claramonte/es'
# [Row 79] (requesting) Query: 'site:linkedin.com/in  Afterbanks Arcopay David Lozano'
#   → Found: 'https://es.linkedin.com/in/javiercanadilla'
# [Row 80] (requesting) Query: 'site:linkedin.com/in  OnTruck Antonio Lu'
#   → Found: 'https://es.linkedin.com/in/antoniolulee'
# [Row 81] (requesting) Query: 'site:linkedin.com/in  OnTruck Gonzalo Parejo Navajas'
#   → Found: 'https://br.linkedin.com/in/gparejonavajas/es'
# [Row 82] (requesting) Query: 'site:linkedin.com/in  OnTruck Inigo Juantegui'
#   → Found: 'https://es.linkedin.com/in/ijuantegui'
# [Row 83] (requesting) Query: 'site:linkedin.com/in  OnTruck Javier Fernandez Escribano'
#   → Found: 'https://es.linkedin.com/in/fesja'
# [Row 84] (requesting) Query: 'site:linkedin.com/in  OnTruck Rika Christanto'
#   → Found: 'https://es.linkedin.com/in/rikachristanto'
# [Row 85] (requesting) Query: 'site:linkedin.com/in  OnTruck Samuel Fuentes'
#   → Found: 'https://es.linkedin.com/in/samuelfuentes'
# [Row 86] (requesting) Query: 'site:linkedin.com/in  tugesto Lidon Serra'
#   → Found: 'https://es.linkedin.com/in/lid%C3%B3n-serra-a68608320'
# [Row 87] (requesting) Query: 'site:linkedin.com/in  tugesto Manuel Fandos'
#   → Found: 'https://es.linkedin.com/in/manuel-fandos'
# [Row 88] (requesting) Query: 'site:linkedin.com/in  HOPU Smart Cities Antonio Jara'
#   → Found: 'https://sa.linkedin.com/in/jara-iot'
# [Row 89] (requesting) Query: 'site:linkedin.com/in  HOPU Smart Cities David Fernández'
#   → Found: 'https://es.linkedin.com/in/david-fern%C3%A1ndez-ros-50823246'
# [Row 90] (requesting) Query: 'site:linkedin.com/in  HOPU Smart Cities Iris Cuevas'
#   → Found: 'https://es.linkedin.com/in/iris-cuevas-martinez-598428b8/en'
# [Row 91] (requesting) Query: 'site:linkedin.com/in  Genially Chema Roldán'
#   → Found: 'https://es.linkedin.com/in/chemaroldan'
# [Row 92] (requesting) Query: 'site:linkedin.com/in  Genially Juan Rubio'
#   → Found: 'https://www.linkedin.com/in/juanrubiolopez'
# [Row 93] (requesting) Query: 'site:linkedin.com/in  Genially Luis García'
#   → Found: 'https://es.linkedin.com/in/luis-garc%C3%ADa-d%C3%ADez-09232a31'
# [Row 94] (requesting) Query: 'site:linkedin.com/in  Instamaki Alberto Bonhomme'
#   → Found: 'https://es.linkedin.com/in/albertobonhomme'
# [Row 95] (requesting) Query: 'site:linkedin.com/in  Frontity Luis Herranz'
#   → Found: 'https://es.linkedin.com/in/luisherranz'
# [Row 96] (requesting) Query: 'site:linkedin.com/in  Frontity Pablo Postigo'
#   → Found: 'https://es.linkedin.com/in/pablopostigodelgado'
# [Row 97] (requesting) Query: 'site:linkedin.com/in  Origo Biopharma Carme Pampín Casal'
#   → Found: 'https://es.linkedin.com/in/sergio-j-montano'
# [Row 98] (requesting) Query: 'site:linkedin.com/in  Mediasmart Alberto Benbunan'
#   → Found: 'https://es.linkedin.com/in/alejandro-gutierrez-bolivar'
# [Row 99] (requesting) Query: 'site:linkedin.com/in  Mediasmart Michael Kleindl'
#   → No organic results; leaving as None
# [Row 100] (requesting) Query: 'site:linkedin.com/in  Mediasmart Noelia Amoedo'
#   → Found: 'https://es.linkedin.com/in/namoedo'
# [Row 101] (requesting) Query: 'site:linkedin.com/in  Ulabox David Baratech'
#   → Found: 'https://es.linkedin.com/in/davidbaratech'
# [Row 102] (requesting) Query: 'site:linkedin.com/in  Ulabox Sergi de Pablos'
#   → No organic results; leaving as None
# [Row 103] (requesting) Query: 'site:linkedin.com/in  chicfy Laura Munoz'
#   → Found: 'https://es.linkedin.com/in/laura-mu%C3%B1oz-gonz%C3%A1lez'
# [Row 104] (requesting) Query: 'site:linkedin.com/in  chicfy Nono Ruiz'
#   → Found: 'https://es.linkedin.com/in/nonorual'
# [Row 105] (requesting) Query: 'site:linkedin.com/in  Datumize Albert Pradell'
#   → No organic results; leaving as None
# [Row 106] (requesting) Query: 'site:linkedin.com/in  Datumize M. C.'
#   → Found: 'https://www.linkedin.com/in/adrian-hinrichsen'
# [Row 107] (requesting) Query: 'site:linkedin.com/in  Datumize Nacho Lafuente'
#   → Found: 'https://es.linkedin.com/in/nacho-lafuente-botella'
# [Row 108] (requesting) Query: 'site:linkedin.com/in  Wide Eyes Long Long Yu'
#   → Found: 'https://es.linkedin.com/in/long-long-yu-5ba62429'
# [Row 109] (requesting) Query: 'site:linkedin.com/in  Wide Eyes Luis Manent'
#   → Found: 'https://es.linkedin.com/in/luismanent'
# [Row 110] (requesting) Query: 'site:linkedin.com/in  Wide Eyes Miguel Pousa'
#   → Found: 'https://es.linkedin.com/in/miguel-pousa-freire-83914633'
# [Row 111] (requesting) Query: 'site:linkedin.com/in  Wide Eyes Rodolfo Guichon'
#   → Found: 'https://es.linkedin.com/in/rodolfo-guichon/en'
# [Row 112] (requesting) Query: 'site:linkedin.com/in  Helloteca Adrian Martinez'
#   → Found: 'https://es.linkedin.com/in/david-vea-mart%C3%ACnez-b22081130'
# [Row 113] (requesting) Query: 'site:linkedin.com/in  Helloteca Juan Pablo Caturini'
#   → Found: 'https://es.linkedin.com/in/juan-pablo-caturini-61a36418b'
# [Row 114] (requesting) Query: 'site:linkedin.com/in  Helloteca Nuria Alvaro Carrasco'
#   → Found: 'https://es.linkedin.com/in/nurialvarocarrasco'
# [Row 115] (requesting) Query: 'site:linkedin.com/in  iSalud.com Albert Castells'
#   → Found: 'https://es.linkedin.com/in/albertcastells'
# [Row 116] (requesting) Query: 'site:linkedin.com/in  iSalud.com Belén Barangé Pons'
#   → Found: 'https://es.linkedin.com/in/bel%C3%A9n-barang%C3%A9-pons-9a4b4331'
# [Row 117] (requesting) Query: 'site:linkedin.com/in  iSalud.com Daniel Pérez'
#   → Found: 'https://es.linkedin.com/in/daniel-perez-rubiales'
# [Row 118] (requesting) Query: 'site:linkedin.com/in  Clicars Carlos Rivera'
#   → Found: 'https://es.linkedin.com/in/carlos-rivera-1488107'
# [Row 119] (requesting) Query: 'site:linkedin.com/in  Clicars Guillaume Paoli'
#   → Found: 'https://fr.linkedin.com/in/karineferreira22/pt'
# [Row 120] (requesting) Query: 'site:linkedin.com/in  Clicars Nicolas Chartier'
#   → Found: 'https://www.linkedin.com/in/michaelreyes/pt'
# [Row 121] (requesting) Query: 'site:linkedin.com/in  Hdiv Security Gorka Vicente'
#   → No organic results; leaving as None
# [Row 122] (requesting) Query: 'site:linkedin.com/in  Hdiv Security Roberto Velasco'
#   → Found: 'https://es.linkedin.com/in/robertovelascosarasola'
# [Row 123] (requesting) Query: 'site:linkedin.com/in  Hdiv Security Ugaitz Urien Crespo'
#   → Found: 'https://es.linkedin.com/in/uurien'
# [Row 124] (requesting) Query: 'site:linkedin.com/in  Entrenarme Diego Moya Nájera'
#   → Found: 'https://es.linkedin.com/in/diegomoyanajera'
# [Row 125] (requesting) Query: 'site:linkedin.com/in  Entrenarme Sebastien Borreani'
#   → Found: 'https://es.linkedin.com/in/diegomoyanajera'
# [Row 126] (requesting) Query: 'site:linkedin.com/in  Agile Content Hernan Scapusio'
#   → Found: 'https://es.linkedin.com/in/hernan-scapusio-2890333'
# [Row 127] (requesting) Query: 'site:linkedin.com/in  Agile Content Monica Rayo'
#   → Found: 'https://es.linkedin.com/in/mrayo'
# [Row 128] (requesting) Query: 'site:linkedin.com/in  21Buttons Jaime Farres Rocabert'
#   → Found: 'https://es.linkedin.com/in/jaime-farres'
# [Row 129] (requesting) Query: 'site:linkedin.com/in  21Buttons Marc Soler Obradors'
#   → Found: 'https://es.linkedin.com/in/marc-soler-obradors-72777b40'
# [Row 130] (requesting) Query: 'site:linkedin.com/in  Upplication Jose Luis Vega de Seoane'
#   → Found: 'https://es.linkedin.com/in/joseluisvds/en'
# [Row 131] (requesting) Query: 'site:linkedin.com/in  Upplication Juan Martínez'
#   → Found: 'https://www.linkedin.com/in/juanamartinez73'
# [Row 132] (requesting) Query: 'site:linkedin.com/in  Upplication Victor Frutos'
#   → Found: 'https://es.linkedin.com/in/victorrodadofrutos'
# [Row 133] (requesting) Query: 'site:linkedin.com/in  Smadex Jordi de los Pinos'
#   → Found: 'https://es.linkedin.com/in/jordipinos'
# [Row 134] (requesting) Query: 'site:linkedin.com/in  Smadex José Ramón Gómez'
#   → Found: 'https://es.linkedin.com/in/jrgomez'
# [Row 135] (requesting) Query: 'site:linkedin.com/in  Smadex Víctor Ruiz'
#   → Found: 'https://es.linkedin.com/in/victoruiz'
# [Row 136] (requesting) Query: 'site:linkedin.com/in  Guesser Carlos Gonzalez Juarez'
#   → Found: 'https://mx.linkedin.com/in/octoks'
# [Row 137] (requesting) Query: 'site:linkedin.com/in  Guesser Jose Garay'
#   → Found: 'https://www.linkedin.com/in/jose-garay-26798ba5'
# [Row 138] (requesting) Query: 'site:linkedin.com/in  Qbitia Francisco Román'
#   → Found: 'https://es.linkedin.com/in/franciscomromanrodriguez/en'
# [Row 139] (requesting) Query: 'site:linkedin.com/in  Qbitia Luis Taboada'
#   → Found: 'https://uk.linkedin.com/in/luistaboadavillamil/en'
# [Row 140] (requesting) Query: 'site:linkedin.com/in  Qbitia Marcos Suárez'
#   → Found: 'https://es.linkedin.com/in/marcossuarezcorral'
# [Row 141] (requesting) Query: 'site:linkedin.com/in  Bucmi Francisco Muñiz'
#   → Found: 'https://es.linkedin.com/in/francisco-mu%C3%B1iz-pav%C3%B3n-690ab125'
# [Row 142] (requesting) Query: 'site:linkedin.com/in  Bucmi Javier Garcia'
#   → Found: 'https://es.linkedin.com/in/javier-garc%C3%ADa-de-la-calera-dassi-4178aa51'
# [Row 143] (requesting) Query: 'site:linkedin.com/in  Bucmi Javier Muñiz'
#   → Found: 'https://es.linkedin.com/in/javierm15'
# [Row 144] (requesting) Query: 'site:linkedin.com/in  Bucmi Jose Sud'
#   → Found: 'https://es.linkedin.com/in/jose-antonio-sud-rom%C3%A1n-30334537'
# [Row 145] (requesting) Query: 'site:linkedin.com/in  Bucmi Pablo Lago'
#   → Found: 'https://es.linkedin.com/in/pablolago/en?trk=public_post-text'
# [Row 146] (requesting) Query: 'site:linkedin.com/in  MyTwinPlace Jean-Noël Saunier'
#   → No organic results; leaving as None
# [Row 147] (requesting) Query: 'site:linkedin.com/in  MyTwinPlace Xavier Laballos'
#   → No organic results; leaving as None
# [Row 148] (requesting) Query: 'site:linkedin.com/in  Tweet Binder Javier Abrego'
#   → Found: 'https://es.linkedin.com/in/fjabrego'
# [Row 149] (requesting) Query: 'site:linkedin.com/in  TripUniq Charles Elias'
#   → Found: 'https://es.linkedin.com/in/charlyelias'
# [Row 150] (requesting) Query: 'site:linkedin.com/in  TripUniq Álvaro Vélez'
#   → No organic results; leaving as None
# [Row 151] (requesting) Query: 'site:linkedin.com/in  Bibulu Enrico Sargiacomo'
#   → Found: 'https://es.linkedin.com/in/enricosargiacomo'
# [Row 152] (requesting) Query: 'site:linkedin.com/in  Bibulu Rafa Terradas'
#   → Found: 'https://es.linkedin.com/in/rafa-terradas-20b5a24'
# [Row 153] (requesting) Query: 'site:linkedin.com/in  Bibulu Tomasz Matuszczyk'
#   → Found: 'https://www.linkedin.com/in/tomaszmatuszczyk'
# [Row 154] (requesting) Query: 'site:linkedin.com/in  GIGAS Diego Cabezudo'
#   → Found: 'https://pt.linkedin.com/in/diegocabezudo'
# [Row 155] (requesting) Query: 'site:linkedin.com/in  GIGAS Jose Antonio Arribas'
#   → Found: 'https://es.linkedin.com/in/jarribas'
# [Row 156] (requesting) Query: 'site:linkedin.com/in  GIGAS Moisés Israel'
#   → Found: 'https://il.linkedin.com/in/moises-israel-abecasis-6630a025'
# [Row 157] (requesting) Query: 'site:linkedin.com/in  GIGAS Walter Kobylanski'
#   → Found: 'https://es.linkedin.com/in/kobylanski'
# [Row 158] (requesting) Query: 'site:linkedin.com/in  Trip4real Gloria Molins'
#   → Found: 'https://es.linkedin.com/in/gloriamolins'
# [Row 159] (requesting) Query: 'site:linkedin.com/in  urbanData Analytics Alberto Santos'
#   → Found: 'https://mx.linkedin.com/in/luis-alberto-aguilar-cervantes-09327a24a'
# [Row 160] (requesting) Query: 'site:linkedin.com/in  urbanData Analytics Carlos Olmos'
#   → Found: 'https://es.linkedin.com/in/carlosolmosarquitecto'
# [Row 161] (requesting) Query: 'site:linkedin.com/in  urbanData Analytics Crescencio Martín'
#   → Found: 'https://es.linkedin.com/in/crescencio-martin-06503852'
# [Row 162] (requesting) Query: 'site:linkedin.com/in  urbanData Analytics Enrique Toribio'
#   → Found: 'https://es.linkedin.com/in/enriquetoribio/en'
# [Row 163] (requesting) Query: 'site:linkedin.com/in  urbanData Analytics Jose Manuel Navarro'
#   → Found: 'https://es.linkedin.com/in/jmnavarro/es'
# [Row 164] (requesting) Query: 'site:linkedin.com/in  Groopify Alejandro Coca'
#   → Found: 'https://es.linkedin.com/in/alejandrococa'
# [Row 165] (requesting) Query: 'site:linkedin.com/in  Groopify Miguel García-Santesmases'
#   → Found: 'https://es.linkedin.com/in/miguelgarciasantesmases'
# [Row 166] (requesting) Query: 'site:linkedin.com/in  Groopify Pablo Viguera'
#   → Found: 'https://mx.linkedin.com/in/viguerapablo'
# [Row 167] (requesting) Query: 'site:linkedin.com/in  Besepa Alberto Molpeceres'
#   → Found: 'https://es.linkedin.com/in/pazfernandezmartin'
# [Row 168] (requesting) Query: 'site:linkedin.com/in  Besepa Gonzalo Valverde'
#   → No organic results; leaving as None
# [Row 169] (requesting) Query: 'site:linkedin.com/in  Qustodio Eduardo Cruz'
#   → Found: 'https://es.linkedin.com/in/edcruz'
# [Row 170] (requesting) Query: 'site:linkedin.com/in  Qustodio Josep Gaspar'
#   → Found: 'https://es.linkedin.com/in/josepgaspar'
# [Row 171] (requesting) Query: 'site:linkedin.com/in  Qustodio Josep Gaspar'
#   → Found: 'https://es.linkedin.com/in/josepgaspar'
# [Row 172] (requesting) Query: 'site:linkedin.com/in  Qustodio Josh Gabel'
#   → Found: 'https://es.linkedin.com/in/josh-gabel'
# [Row 173] (requesting) Query: 'site:linkedin.com/in  GymForLess Guillermo Ceballos'
#   → Found: 'https://es.linkedin.com/in/ilopezluna/en?trk=public_post_main-feed-card-text'
# [Row 174] (requesting) Query: 'site:linkedin.com/in  GymForLess Guillermo Llibre'
#   → No organic results; leaving as None
# [Row 175] (requesting) Query: 'site:linkedin.com/in  GymForLess Joaquin Engel'
#   → No organic results; leaving as None
# [Row 176] (requesting) Query: 'site:linkedin.com/in  GymForLess Miguel Abadias'
#   → No organic results; leaving as None
# [Row 177] (requesting) Query: 'site:linkedin.com/in  GymForLess Oriol Vinzia'
#   → Found: 'https://es.linkedin.com/in/oriolvinzia'
# [Row 178] (requesting) Query: 'site:linkedin.com/in  Playspace Alfonso Villar'
#   → Found: 'https://www.linkedin.com/in/alfonsovillar/'
# [Row 179] (requesting) Query: 'site:linkedin.com/in  Playspace Enrique Dubois'
#   → No organic results; leaving as None
# [Row 180] (requesting) Query: 'site:linkedin.com/in  Dinantia Borja Berenguer'
#   → Found: 'https://es.linkedin.com/in/borja-berenguer-411a971'
# [Row 181] (requesting) Query: 'site:linkedin.com/in  Dinantia Cristian Cisa'
#   → Found: 'https://es.linkedin.com/in/cristiancisa'
# [Row 182] (requesting) Query: 'site:linkedin.com/in  Tiendeo Eva Martin'
#   → Found: 'https://es.linkedin.com/in/evavillaro'
# [Row 183] (requesting) Query: 'site:linkedin.com/in  Tiendeo Jonathan Lemberger'
#   → Found: 'https://es.linkedin.com/in/lemberger'
# [Row 184] (requesting) Query: 'site:linkedin.com/in  Tiendeo Maria Martin Villaro'
#   → Found: 'https://es.linkedin.com/in/maria-mart%C3%ADn-villar%C3%B3-3b49828'
# [Row 185] (requesting) Query: 'site:linkedin.com/in  ADman Media Josep Maria Tribo'
#   → Found: 'https://es.linkedin.com/in/jmtribo'
# [Row 186] (requesting) Query: 'site:linkedin.com/in  ADman Media Marcos Luengo'
#   → Found: 'https://es.linkedin.com/in/marcosluengo'
# [Row 187] (requesting) Query: 'site:linkedin.com/in  ADman Media Victor Sala'
#   → Found: 'https://es.linkedin.com/in/victorsala'
# [Row 188] (requesting) Query: 'site:linkedin.com/in  Catchoom David Marimon'
#   → Found: 'https://es.linkedin.com/in/davidmarimon'
# [Row 189] (requesting) Query: 'site:linkedin.com/in  Catchoom Tomasz Adamek'
#   → Found: 'https://es.linkedin.com/in/tadamek'
# [Row 190] (requesting) Query: 'site:linkedin.com/in  Stream Hatchet Albert Alemany'
#   → Found: 'https://es.linkedin.com/in/albertalemanyfont'
# [Row 191] (requesting) Query: 'site:linkedin.com/in  Stream Hatchet Albert Benitez'
#   → Found: 'https://es.linkedin.com/in/benitezalbert'
# [Row 192] (requesting) Query: 'site:linkedin.com/in  Stream Hatchet Eduard Montserrat'
#   → Found: 'https://es.linkedin.com/in/eduardmontserrat'
# [Row 193] (requesting) Query: 'site:linkedin.com/in  Tyba Eiso Kant'
#   → Found: 'https://by.linkedin.com/in/yuliya-sidor-40625815b'
# [Row 194] (requesting) Query: 'site:linkedin.com/in  Tyba Jorge Schnura'
#   → Found: 'https://es.linkedin.com/in/jorgeschnura'
# [Row 195] (requesting) Query: 'site:linkedin.com/in  Tyba Philip von Have'
#   → Found: 'https://de.linkedin.com/in/philip-von-have-29b46a20'
# [Row 196] (requesting) Query: 'site:linkedin.com/in  Bodas.net Nina Perez'
#   → Found: 'https://es.linkedin.com/in/nina-perez-7096114'
# [Row 197] (requesting) Query: 'site:linkedin.com/in  Blink Booking Rebeca Minguela'
#   → Found: 'https://www.linkedin.com/in/rebecaminguela'
# [Row 198] (requesting) Query: 'site:linkedin.com/in  Ducksboard Aitor Guevara'
#   → Found: 'https://es.linkedin.com/in/aitorciki'
# [Row 199] (requesting) Query: 'site:linkedin.com/in  Ducksboard Diego Mariño'
#   → Found: 'https://es.linkedin.com/in/diegomarinoroman'
# [Row 200] (requesting) Query: 'site:linkedin.com/in  Ducksboard Jan Urbański'
#   → Found: 'https://pl.linkedin.com/in/jan-urba%C5%84ski-290b3395'
# [Row 201] (requesting) Query: 'site:linkedin.com/in  Inspiring Benefits Javier Diez'
#   → Found: 'https://es.linkedin.com/in/javierdiezflaquer'
# [Row 202] (requesting) Query: 'site:linkedin.com/in  Inspiring Benefits Javier Reyes'
#   → Found: 'https://es.linkedin.com/in/javiersanchezreyes'
# [Row 203] (requesting) Query: 'site:linkedin.com/in  Inspiring Benefits Jose Morales'
#   → Found: 'https://www.linkedin.com/in/jose-morales-a330079b'
# [Row 204] (requesting) Query: 'site:linkedin.com/in  Gana Energía Antonio Picazo'
#   → Found: 'https://es.linkedin.com/in/antonio-picazo-lahiguera-ba447423'
# [Row 205] (requesting) Query: 'site:linkedin.com/in  Gana Energía Ricardo Margalejo'
#   → Found: 'https://es.linkedin.com/in/ricardo-margalejo-a16a8431'
# [Row 206] (requesting) Query: 'site:linkedin.com/in  EscapadaRural Fabio Núñez Iturriaga'
#   → Found: 'https://es.linkedin.com/in/fabionunez'
# [Row 207] (requesting) Query: 'site:linkedin.com/in  EscapadaRural Gus Bertolo'
#   → Found: 'https://es.linkedin.com/in/gusbertolo'
# [Row 208] (requesting) Query: 'site:linkedin.com/in  marmota Gerard Olive'
#   → Found: 'https://es.linkedin.com/in/gerardolive/es'
# [Row 209] (requesting) Query: 'site:linkedin.com/in  marmota Toni Estellé'
#   → Found: 'https://es.linkedin.com/in/toni-estell%C3%A9-catal%C3%A0-a2691420'
# [Row 210] (requesting) Query: 'site:linkedin.com/in  Lucera David Zaragoza'
#   → Found: 'https://es.linkedin.com/in/dzaragoza'
# [Row 211] (requesting) Query: 'site:linkedin.com/in  Lucera Emilio Bravo Bayarri'
#   → No organic results; leaving as None
# [Row 212] (requesting) Query: 'site:linkedin.com/in  Lucera Josep Planells Alòs'
#   → Found: 'https://es.linkedin.com/in/joplaal'
# [Row 213] (requesting) Query: 'site:linkedin.com/in  Lucera Richard Chamorro'
#   → Found: 'https://es.linkedin.com/in/richardchamorro'
# [Row 214] (requesting) Query: 'site:linkedin.com/in  TouristEye Ariel Camus'
#   → Found: 'https://es.linkedin.com/in/arielcamus'
# [Row 215] (requesting) Query: 'site:linkedin.com/in  TouristEye Javier Fernandez Escribano'
#   → Found: 'https://es.linkedin.com/in/fesja'
# [Row 216] (requesting) Query: 'site:linkedin.com/in  nubelo Francesc Font'
#   → Found: 'https://es.linkedin.com/in/francescfontcot'
# [Row 217] (requesting) Query: 'site:linkedin.com/in  nubelo Hugo Melero'
#   → Found: 'https://es.linkedin.com/in/hugomelero'
# [Row 218] (requesting) Query: 'site:linkedin.com/in  nubelo Jorge Muller'
#   → Found: 'https://es.linkedin.com/in/jorgearaujomuller/en'
# [Row 219] (requesting) Query: 'site:linkedin.com/in  nubelo Marcos Sanchez'
#   → Found: 'https://es.linkedin.com/in/marcosasanchez/es'
# [Row 220] (requesting) Query: 'site:linkedin.com/in  nubelo Nicolas Muller'
#   → Found: 'https://es.linkedin.com/in/nicolasam1'
# [Row 221] (requesting) Query: 'site:linkedin.com/in  nubelo Rodrigo Villatoro'
#   → Found: 'https://es.linkedin.com/in/rodrigovillatoro'
# [Row 222] (requesting) Query: 'site:linkedin.com/in  ClubKviar Christopher Fuchs'
#   → Found: 'https://es.linkedin.com/in/christopher-fuchs-65a2a148'
# [Row 223] (requesting) Query: 'site:linkedin.com/in  ClubKviar Gonzalo Cebrian'
#   → Found: 'https://es.linkedin.com/in/gonzaloplaza'
# [Row 224] (requesting) Query: 'site:linkedin.com/in  ClubKviar Stewart Masters'
#   → Found: 'https://es.linkedin.com/in/stewartmasters'
# [Row 225] (requesting) Query: 'site:linkedin.com/in  Quolaw Lorella Jalles'
#   → Found: 'https://ar.linkedin.com/in/lorellajalles'
# [Row 226] (requesting) Query: 'site:linkedin.com/in  Quolaw Yael Frylinsztein'
#   → Found: 'https://ar.linkedin.com/in/yael-frylinsztein-45b58440'
# [Row 227] (requesting) Query: 'site:linkedin.com/in  Hotelerum Humbert Torroella'
#   → Found: 'https://es.linkedin.com/in/humbert'
# [Row 228] (requesting) Query: 'site:linkedin.com/in  Erle Robotics Carlos Uraga'
#   → Found: 'https://www.linkedin.com/in/carlos-uraga-779ab929/'
# [Row 229] (requesting) Query: 'site:linkedin.com/in  Erle Robotics David Mayoral'
#   → Found: 'https://www.linkedin.com/in/davidmayoralvilches/'
# [Row 230] (requesting) Query: 'site:linkedin.com/in  The Fab Shoes Francisco de la Calle'
#   → Found: 'https://www.linkedin.com/in/carlos-calle-2b948a13'
# [Row 231] (requesting) Query: 'site:linkedin.com/in  The Fab Shoes Pablo Szefner'
#   → Found: 'https://es.linkedin.com/in/pabloszefner'
# [Row 232] (requesting) Query: 'site:linkedin.com/in  The Fab Shoes Xisco Calle'
#   → No organic results; leaving as None
# [Row 233] (requesting) Query: 'site:linkedin.com/in  Blissbooker Boris Hageney'
#   → Found: 'https://es.linkedin.com/in/hageney'
# [Row 234] (requesting) Query: 'site:linkedin.com/in  Signadyne Marc Almendros'
#   → Found: 'https://es.linkedin.com/in/marc-almendros-03835518/es'
# [Row 235] (requesting) Query: 'site:linkedin.com/in  Signadyne Nestor Oliverio'
#   → Found: 'https://es.linkedin.com/in/nestor-h-oliverio-ba468911'
# [Row 236] (requesting) Query: 'site:linkedin.com/in  PopPlaces David Perez'
#   → Found: 'https://es.linkedin.com/in/davidperezcorral'
# [Row 237] (requesting) Query: 'site:linkedin.com/in  PopPlaces Karen Prats'
#   → Found: 'https://de.linkedin.com/in/karenprats/en'
# [Row 238] (requesting) Query: 'site:linkedin.com/in  Icebergs Albert Pereta'
#   → No organic results; leaving as None
# [Row 239] (requesting) Query: 'site:linkedin.com/in  Icebergs César Isern'
#   → Found: 'https://es.linkedin.com/in/cesarisern'
# [Row 240] (requesting) Query: 'site:linkedin.com/in  ChicPlace Gerard Olive'
#   → No organic results; leaving as None
# [Row 241] (requesting) Query: 'site:linkedin.com/in  ChicPlace Marta Antunez'
#   → Found: 'https://es.linkedin.com/in/martaantunez'
# [Row 242] (requesting) Query: 'site:linkedin.com/in  ChicPlace Miguel Vicente'
#   → Found: 'https://es.linkedin.com/in/gonzalomiguez/en'
# [Row 243] (requesting) Query: 'site:linkedin.com/in  ChicPlace Sergi Pastor'
#   → Found: 'https://es.linkedin.com/in/gonzalomiguez/en'
# [Row 244] (requesting) Query: 'site:linkedin.com/in  GOVERTIS Advisory Services Óscar Bou Bou'
#   → Found: 'https://es.linkedin.com/in/oscarbou'
# [Row 245] (requesting) Query: 'site:linkedin.com/in  Saluspot Carlos Schmitz'
#   → No organic results; leaving as None
# [Row 246] (requesting) Query: 'site:linkedin.com/in  Saluspot Fernando Marquez'
#   → Found: 'https://es.linkedin.com/in/fernando-marquez-93735010'
# [Row 247] (requesting) Query: 'site:linkedin.com/in  Saluspot Gonzalo Castellano'
#   → Found: 'https://es.linkedin.com/in/gonzalo-castellano-4730337'
# [Row 248] (requesting) Query: 'site:linkedin.com/in  Saluspot Philipp Hasskamp'
#   → Found: 'https://co.linkedin.com/in/phasskamp'
# [Row 249] (requesting) Query: 'site:linkedin.com/in  Otogami David Bonilla Fuertes'
#   → Found: 'https://es.linkedin.com/in/dbonillaf'
# [Row 250] (requesting) Query: 'site:linkedin.com/in  Otogami Jerónimo López'
#   → Found: 'https://es.linkedin.com/in/candelamilan'
# [Row 251] (requesting) Query: 'site:linkedin.com/in  Nonabox Gustavo Garcia'
#   → Found: 'https://es.linkedin.com/in/perichus/en'
# [Row 252] (requesting) Query: 'site:linkedin.com/in  Nonabox Izanami Martinez'
#   → Found: 'https://es.linkedin.com/in/izanami'
# [Row 253] (requesting) Query: 'site:linkedin.com/in  Nonabox Ramon Domenech'
#   → Found: 'https://es.linkedin.com/in/rsdsanchez/en'
# [Row 254] (requesting) Query: 'site:linkedin.com/in  Motobuykers Eric Ubals'
#   → Found: 'https://es.linkedin.com/in/eric-ubals'
# [Row 255] (requesting) Query: 'site:linkedin.com/in  Rollbox Ismael Sanchez'
#   → Found: 'https://es.linkedin.com/in/ismael-s%C3%A1nchez-soriano-7869b433'
# [Row 256] (requesting) Query: 'site:linkedin.com/in  Rollbox Xavi Leal'
#   → Found: 'https://es.linkedin.com/in/lealxavi'
# [Row 257] (requesting) Query: 'site:linkedin.com/in  Naco Technologies Alexander Parfinovich'
#   → Found: 'https://lv.linkedin.com/in/aleksandrs-parfinovics-27468a'
# [Row 258] (requesting) Query: 'site:linkedin.com/in  Naco Technologies Eduard Parfinovich'
#   → Found: 'https://lv.linkedin.com/in/eduard-parfinovich-7361a9341'
# [Row 259] (requesting) Query: 'site:linkedin.com/in  Naco Technologies Valery Mitin'
#   → No organic results; leaving as None
# [Row 260] (requesting) Query: 'site:linkedin.com/in  Airdog Agris Kipurs'
#   → Found: 'https://lv.linkedin.com/in/agris-kipurs-68215134'
# [Row 261] (requesting) Query: 'site:linkedin.com/in  Airdog Edgars Rozentals'
#   → Found: 'https://lv.linkedin.com/in/edgarsrozentals'
# [Row 262] (requesting) Query: 'site:linkedin.com/in  Airdog Ilja Nevdahs'
#   → Found: 'https://lv.linkedin.com/in/iljanevdahs'
# [Row 263] (requesting) Query: 'site:linkedin.com/in  Nordigen Roberts Bernans'
#   → Found: 'https://lv.linkedin.com/in/roberts-bernans-87264b17'
# [Row 264] (requesting) Query: 'site:linkedin.com/in  Nordigen Rolands Mesters'
#   → Found: 'https://lv.linkedin.com/in/rolands-mesters-b60504325'
# [Row 265] (requesting) Query: 'site:linkedin.com/in  Roibox Edvarts Gaigals'
#   → Found: 'https://lv.linkedin.com/in/edvartsgaigals'
# [Row 266] (requesting) Query: 'site:linkedin.com/in  Roibox Jekabs Endzins'
#   → Found: 'https://lv.linkedin.com/in/zigmarsrudzitis'
# [Row 267] (requesting) Query: 'site:linkedin.com/in  Infogram Alise Semjonova'
#   → Found: 'https://www.linkedin.com/in/rayne-yuen-7170aa102'
# [Row 268] (requesting) Query: 'site:linkedin.com/in  Infogram Raimonds Kaže'
#   → Found: 'https://lv.linkedin.com/in/kazhe'
# [Row 269] (requesting) Query: 'site:linkedin.com/in  Infogram Uldis Leiterts'
#   → Found: 'https://lv.linkedin.com/in/laura-vanaga-bbb6b242'
# [Row 270] (requesting) Query: 'site:linkedin.com/in  Mailigen Janis Rose'
#   → Found: 'https://lv.linkedin.com/in/viktorija-jakovleva'
# [Row 271] (requesting) Query: 'site:linkedin.com/in  DeepL Jaroslaw Kutylowski'
#   → Found: 'https://de.linkedin.com/in/jarekkut'
# [Row 272] (requesting) Query: 'site:linkedin.com/in  Lilium Patrick Nathen'
#   → Found: 'https://de.linkedin.com/in/dr-patrick-nathen-1a0840b3'
# [Row 273] (requesting) Query: 'site:linkedin.com/in  Quantum Systems Armin Busse'
#   → Found: 'https://de.linkedin.com/in/armin-busse-6092656b'
# [Row 274] (requesting) Query: 'site:linkedin.com/in  Quantum Systems Florian Seibel'
#   → Found: 'https://de.linkedin.com/in/florian-seibel-8a78b99b'
# [Row 275] (requesting) Query: 'site:linkedin.com/in  Forto Erik Muttersbach'
#   → Found: 'https://de.linkedin.com/in/erikmuttersbach'
# [Row 276] (requesting) Query: 'site:linkedin.com/in  Forto Fabian Heilemann'
#   → Found: 'https://www.linkedin.com/in/ferry-heilemann'
# [Row 277] (requesting) Query: 'site:linkedin.com/in  Forto Ferry Heilemann'
#   → Found: 'https://www.linkedin.com/in/ferry-heilemann'
# [Row 278] (requesting) Query: 'site:linkedin.com/in  Forto Michael Wax'
#   → Found: 'https://de.linkedin.com/in/mikewax'
# [Row 279] (requesting) Query: 'site:linkedin.com/in  OKAPI:Orbits Christopher Kebschull'
#   → Found: 'https://de.linkedin.com/in/christopher-kebschull-215331157'
# [Row 280] (requesting) Query: 'site:linkedin.com/in  OKAPI:Orbits Jonas Radtke'
#   → Found: 'https://de.linkedin.com/in/jonas-radtke-991672172'
# [Row 281] (requesting) Query: 'site:linkedin.com/in  OKAPI:Orbits Kristina Nikolaus'
#   → Found: 'https://www.linkedin.com/in/kristina-nikolaus-8b586211a/'
# [Row 282] (requesting) Query: 'site:linkedin.com/in  Parloa Malte Kosub'
#   → Found: 'https://www.linkedin.com/in/maltekosub'
# [Row 283] (requesting) Query: 'site:linkedin.com/in  Parloa Stefan Ostwald'
#   → Found: 'https://de.linkedin.com/in/stefanostwald'
# [Row 284] (requesting) Query: 'site:linkedin.com/in  Upvest Juha Ristolainen'
#   → Found: 'https://ca.linkedin.com/in/valson'
# [Row 285] (requesting) Query: 'site:linkedin.com/in  Upvest Martin Kassing'
#   → Found: 'https://de.linkedin.com/in/martin-kassing'
# [Row 286] (requesting) Query: 'site:linkedin.com/in  Upvest Til Rochow'
#   → Found: 'https://de.linkedin.com/in/tilrochow'
# [Row 287] (requesting) Query: 'site:linkedin.com/in  Upvest Tobias Auferoth'
#   → Found: 'https://de.linkedin.com/in/auferoth'
# [Row 288] (requesting) Query: 'site:linkedin.com/in  Hawk Tobias Schweiger'
#   → Found: 'https://de.linkedin.com/in/schweiger'
# [Row 289] (requesting) Query: 'site:linkedin.com/in  Hawk Wolfgang Berner'
#   → Found: 'https://at.linkedin.com/in/wolfgang-berner-096bb34'
# [Row 290] (requesting) Query: 'site:linkedin.com/in  Noxtua Felix Hahmann'
#   → No organic results; leaving as None
# [Row 291] (requesting) Query: 'site:linkedin.com/in  Noxtua Leif Nissen Lundbaek'
#   → Found: 'https://de.linkedin.com/in/leif-nissen-lundb%C3%A6k-phd-a00a32141'
# [Row 292] (requesting) Query: 'site:linkedin.com/in  Noxtua Michael Huth'
#   → Found: 'https://uk.linkedin.com/in/michael-huth-b5109917'
# [Row 293] (requesting) Query: 'site:linkedin.com/in  Buynomics Emilio Matthaei'
#   → Found: 'https://de.linkedin.com/in/emiliomatthaei'
# [Row 294] (requesting) Query: 'site:linkedin.com/in  Buynomics Ingo Reinhardt'
#   → Found: 'https://de.linkedin.com/in/ingoreinhardt'
# [Row 295] (requesting) Query: 'site:linkedin.com/in  Buynomics Sebastian Baier'
#   → Found: 'https://de.linkedin.com/in/sebastian-baier/en'
# [Row 296] (requesting) Query: 'site:linkedin.com/in  CoachHub Matti Niebelschuetz'
#   → Found: 'https://de.linkedin.com/in/niebelschuetz'
# [Row 297] (requesting) Query: 'site:linkedin.com/in  CoachHub Yannis Niebelschuetz'
#   → Found: 'https://www.linkedin.com/in/yniebelschuetz'
# [Row 298] (requesting) Query: 'site:linkedin.com/in  TWAICE Michael Baumann'
#   → Found: 'https://de.linkedin.com/in/dr-michael-baumann-31868b113'
# [Row 299] (requesting) Query: 'site:linkedin.com/in  TWAICE Stephan Rohr'
#   → Found: 'https://de.linkedin.com/in/dr-stephan-rohr-01a353a7'
# [Row 300] (requesting) Query: 'site:linkedin.com/in  Solaris Andreas Bittner'
#   → Found: 'https://de.linkedin.com/in/andreas-bittner'
# [Row 301] (requesting) Query: 'site:linkedin.com/in  Solaris Marko Wenthin'
#   → Found: 'https://de.linkedin.com/in/markowenthin/en'
# [Row 302] (requesting) Query: 'site:linkedin.com/in  LiveEO Daniel Seidel'
#   → Found: 'https://de.linkedin.com/in/daniel-seidel-979524137'
# [Row 303] (requesting) Query: 'site:linkedin.com/in  LiveEO Sven Przywarra'
#   → Found: 'https://de.linkedin.com/in/svenprzy'
# [Row 304] (requesting) Query: 'site:linkedin.com/in  Grover Michael Cassau'
#   → Found: 'https://de.linkedin.com/in/gibrankm'
# [Row 305] (requesting) Query: 'site:linkedin.com/in  German Bionic Armin G. Schmidt'
#   → Found: 'https://de.linkedin.com/in/arminschmidt'
# [Row 306] (requesting) Query: 'site:linkedin.com/in  German Bionic Dirk Pöschl'
#   → Found: 'https://fr.linkedin.com/in/dirk-p%C3%B6schl-aa4a485'
# [Row 307] (requesting) Query: 'site:linkedin.com/in  German Bionic Dr. Peter Heiligensetzer'
#   → Found: 'https://de.linkedin.com/in/peter-heiligensetzer'
# [Row 308] (requesting) Query: 'site:linkedin.com/in  German Bionic Michael Halbherr'
#   → No organic results; leaving as None
# [Row 309] (requesting) Query: 'site:linkedin.com/in  Pitch Adam Renklint'
#   → Found: 'https://de.linkedin.com/in/adam-renklint'
# [Row 310] (requesting) Query: 'site:linkedin.com/in  Pitch Charlette Prevot'
#   → Found: 'https://de.linkedin.com/in/charletteprevot'
# [Row 311] (requesting) Query: 'site:linkedin.com/in  Pitch Christian Reber'
#   → Found: 'https://de.linkedin.com/in/christianreber'
# [Row 312] (requesting) Query: 'site:linkedin.com/in  Pitch Eric Labod'
#   → Found: 'https://de.linkedin.com/in/ericlabod'
# [Row 313] (requesting) Query: 'site:linkedin.com/in  Pitch Jan Martin'
#   → Found: 'https://de.linkedin.com/in/janmartin2'
# [Row 314] (requesting) Query: 'site:linkedin.com/in  Pitch Marvin Labod'
#   → Found: 'https://de.linkedin.com/in/marvinlabod'
# [Row 315] (requesting) Query: 'site:linkedin.com/in  Pitch Misha Karpenko'
#   → Found: 'https://de.linkedin.com/in/mishakarpenko'
# [Row 316] (requesting) Query: 'site:linkedin.com/in  Pitch Vanessa Stock'
#   → Found: 'https://de.linkedin.com/in/vstock'
# [Row 317] (requesting) Query: 'site:linkedin.com/in  ikas Mustafa Namoglu'
#   → Found: 'https://tr.linkedin.com/in/namoglu'
# [Row 318] (requesting) Query: 'site:linkedin.com/in  ikas Omercan Celikler'
#   → Found: 'https://tr.linkedin.com/in/omercancelikler'
# [Row 319] (requesting) Query: 'site:linkedin.com/in  ikas Tugay Karaçay'
#   → Found: 'https://tr.linkedin.com/in/tugaykaracay'
# [Row 320] (requesting) Query: 'site:linkedin.com/in  ikas Umut Ozan Yildirim'
#   → Found: 'https://tr.linkedin.com/in/umut-ozan-yildirim-4518a57a'
# [Row 321] (requesting) Query: 'site:linkedin.com/in  Instagrid Andreas Sedlmayr'
#   → Found: 'https://de.linkedin.com/in/andreas-sedlmayr'
# [Row 322] (requesting) Query: 'site:linkedin.com/in  Instagrid Sebastian Berning'
#   → Found: 'https://de.linkedin.com/in/sebastian-berning'
# [Row 323] (requesting) Query: 'site:linkedin.com/in  Choco Daniel Khachab'
#   → Found: 'https://de.linkedin.com/in/danielkhachab'
# [Row 324] (requesting) Query: 'site:linkedin.com/in  Choco Julian Hammer'
#   → Found: 'https://de.linkedin.com/in/julianhammer'
# [Row 325] (requesting) Query: 'site:linkedin.com/in  Choco Rogério Da Silva Yokomizo'
#   → Found: 'https://de.linkedin.com/in/rogerio-da-silva-yokomizo'
# [Row 326] (requesting) Query: 'site:linkedin.com/in  airfocus Christian Hoffmeister'
#   → Found: 'https://de.linkedin.com/in/choffmeister'
# [Row 327] (requesting) Query: 'site:linkedin.com/in  airfocus Malte Scholz'
#   → Found: 'https://de.linkedin.com/in/maltescholz/de?trk=public_post_comment_actor-image'
# [Row 328] (requesting) Query: 'site:linkedin.com/in  airfocus Valentin Firak'
#   → Found: 'https://de.linkedin.com/in/valentinfirak'
# [Row 329] (requesting) Query: 'site:linkedin.com/in  SoSafe Felix Schuerholz'
#   → Found: 'https://de.linkedin.com/in/felix-sch%C3%BCrholz-66992193'
# [Row 330] (requesting) Query: 'site:linkedin.com/in  SoSafe Lukas Schaefer'
#   → Found: 'https://de.linkedin.com/in/lukas-schaefer-sosafe'
# [Row 331] (requesting) Query: 'site:linkedin.com/in  SoSafe Niklas Hellemann'
#   → Found: 'https://de.linkedin.com/in/nhellemann'
# [Row 332] (requesting) Query: 'site:linkedin.com/in  air up Fabian Schlang'
#   → Found: 'https://de.linkedin.com/in/fabianschlang'
# [Row 333] (requesting) Query: 'site:linkedin.com/in  air up Jannis Koppitz'
#   → Found: 'https://de.linkedin.com/in/jannis-koppitz-0b634bbb'
# [Row 334] (requesting) Query: 'site:linkedin.com/in  air up Lena Jüngst'
#   → Found: 'https://de.linkedin.com/in/lena-juengst'
# [Row 335] (requesting) Query: 'site:linkedin.com/in  air up Simon Nüesch'
#   → Found: 'https://de.linkedin.com/in/simon-nueesch'
# [Row 336] (requesting) Query: 'site:linkedin.com/in  air up Tim Jäger'
#   → Found: 'https://de.linkedin.com/in/tim-j%C3%A4ger-0748bb8a'
# [Row 337] (requesting) Query: 'site:linkedin.com/in  Moonfare Alexander Argyros'
#   → Found: 'https://de.linkedin.com/in/alexander-argyros-92a514b'
# [Row 338] (requesting) Query: 'site:linkedin.com/in  Moonfare Heinrich von Liechtenstein'
#   → Found: 'https://es.linkedin.com/in/heinrich-liechtenstein-4023621'
# [Row 339] (requesting) Query: 'site:linkedin.com/in  Moonfare Steffen Pauls'
#   → Found: 'https://de.linkedin.com/in/steffen-pauls'
# [Row 340] (requesting) Query: 'site:linkedin.com/in  Cara Care Andre Sommer'
#   → Found: 'https://de.linkedin.com/in/andresommer'
# [Row 341] (requesting) Query: 'site:linkedin.com/in  Cara Care Dankrad Feist'
#   → Found: 'https://wf.linkedin.com/in/amory-f-fitzer-django-345527154'
# [Row 342] (requesting) Query: 'site:linkedin.com/in  Cara Care Jesaja Brinkmann'
#   → Found: 'https://de.linkedin.com/in/jesajabrinkmann'
# [Row 343] (requesting) Query: 'site:linkedin.com/in  Cara Care Orest Tarasiuk'
#   → Found: 'https://pl.linkedin.com/in/orestta'
# [Row 344] (requesting) Query: 'site:linkedin.com/in  Formo Britta Winterberg'
#   → Found: 'https://de.linkedin.com/in/dr-britta-winterberg-a3663316b'
# [Row 345] (requesting) Query: 'site:linkedin.com/in  Formo Raffael Wohlgensinger'
#   → Found: 'https://de.linkedin.com/in/raffael-wohlgensinger/en'
# [Row 346] (requesting) Query: 'site:linkedin.com/in  HeyJobs Marius Jeuck'
#   → Found: 'https://de.linkedin.com/in/marius-jeuck'
# [Row 347] (requesting) Query: 'site:linkedin.com/in  HeyJobs Marius Luther'
#   → Found: 'https://de.linkedin.com/in/mariusluther'
# [Row 348] (requesting) Query: 'site:linkedin.com/in  Taxfix Lino Teuteberg'
#   → Found: 'https://de.linkedin.com/in/linoteuteberg'
# [Row 349] (requesting) Query: 'site:linkedin.com/in  Taxfix Mathis Buchi'
#   → Found: 'https://ch.linkedin.com/in/mathisbuechi'
# [Row 350] (requesting) Query: 'site:linkedin.com/in  vivenu Jens Teichert'
#   → Found: 'https://de.linkedin.com/in/jens-teichert-a5b3ab7a'
# [Row 351] (requesting) Query: 'site:linkedin.com/in  vivenu Simon Hennes'
#   → Found: 'https://de.linkedin.com/in/simon-hennes'
# [Row 352] (requesting) Query: 'site:linkedin.com/in  vivenu Simon Weber'
#   → Found: 'https://de.linkedin.com/in/simon-weber-341847197'
# ...
#   → Found: 'https://de.linkedin.com/in/frengel'
# [Row 1882] (requesting) Query: 'site:linkedin.com/in  Zitra.com Philipp Kraft'
#   → Found: 'https://de.linkedin.com/in/kraftphilipp'
# [Row 1883] (requesting) Query: 'site:linkedin.com/in  Meine Spielzeugkiste Florian Metz'
#   → No organic results; leaving as None
# [Row 1884] (requesting) Query: 'site:linkedin.com/in  Meine Spielzeugkiste Florian Spathelf'
#   → No organic results; leaving as None
# [Row 1885] (requesting) Query: 'site:linkedin.com/in  Madvertise Carsten Frien'
#   → No organic results; leaving as None
# [Row 1886] (requesting) Query: 'site:linkedin.com/in  Madvertise Jan Beckers'
#   → No organic results; leaving as None
# [Row 1887] (requesting) Query: 'site:linkedin.com/in  Madvertise Martin Karlsch'
#   → No organic results; leaving as None
# [Row 1888] (requesting) Query: 'site:linkedin.com/in  Madvertise Pan Katsukis'
#   → Found: 'https://de.linkedin.com/in/katsukis'
# [Row 1889] (requesting) Query: 'site:linkedin.com/in  Madvertise Thomas Hille'
#   → No organic results; leaving as None
# [Row 1890] (requesting) Query: 'site:linkedin.com/in  doctape Sascha-Manuel Reuter'
#   → No organic results; leaving as None
# [Row 1891] (requesting) Query: 'site:linkedin.com/in  apiOmat Lutz Kohl'
#   → Found: 'https://de.linkedin.com/in/lutzkohl'
# [Row 1892] (requesting) Query: 'site:linkedin.com/in  apiOmat Marcel Etzel'
#   → Found: 'https://de.linkedin.com/in/marceletzel/en'
# [Row 1893] (requesting) Query: 'site:linkedin.com/in  apiOmat Michael Reiserer'
#   → No organic results; leaving as None
# [Row 1894] (requesting) Query: 'site:linkedin.com/in  apiOmat Philipp Michel'
#   → Found: 'https://de.linkedin.com/in/philipp-michel-036bb5b3'
# [Row 1895] (requesting) Query: 'site:linkedin.com/in  apiOmat Saskia Etzel'
#   → Found: 'https://de.linkedin.com/in/saskia-etzel-bab70773'
# [Row 1896] (requesting) Query: 'site:linkedin.com/in  eZelleron Sascha Kuehn'
#   → Found: 'https://www.linkedin.com/in/drkuehn'
# [Row 1897] (requesting) Query: 'site:linkedin.com/in  Salonmeister Louis Pfitzner'
#   → No organic results; leaving as None
# [Row 1898] (requesting) Query: 'site:linkedin.com/in  Salonmeister Nils Griess-Nega'
#   → No organic results; leaving as None
# [Row 1899] (requesting) Query: 'site:linkedin.com/in  Salonmeister Phillipp Rechberg'
#   → No organic results; leaving as None
# [Row 1900] (requesting) Query: 'site:linkedin.com/in  textunes Michael Oesterreich'
#   → No organic results; leaving as None
# [Row 1901] (requesting) Query: 'site:linkedin.com/in  textunes Simon Seeger'
#   → No organic results; leaving as None
# [Row 1902] (requesting) Query: 'site:linkedin.com/in  textunes Volker Oppmann'
#   → Found: 'https://de.linkedin.com/in/volker-oppmann-927b3b4b'
# [Row 1903] (requesting) Query: 'site:linkedin.com/in  Bloomy Days Franziska v. Hardenberg'
#   → No organic results; leaving as None
# [Row 1904] (requesting) Query: 'site:linkedin.com/in  Kirondo Christopher Deckert'
#   → No organic results; leaving as None
# [Row 1905] (requesting) Query: 'site:linkedin.com/in  Kirondo Michael Rüffer'
#   → No organic results; leaving as None
# [Row 1906] (requesting) Query: 'site:linkedin.com/in  Secusmart Christoph Erdmann'
#   → Found: 'https://de.linkedin.com/in/christoph-erdmann-69856b5'
# [Row 1907] (requesting) Query: 'site:linkedin.com/in  ZIM Plant Technology GmbH Ulrich Zimmermann'
#   → Found: 'https://de.linkedin.com/in/ulrich-zimmermann-mail-53b102136'
# [Row 1908] (requesting) Query: 'site:linkedin.com/in  9Cookies Ian Formanek'
#   → Found: 'https://de.linkedin.com/in/ianformanek'
# [Row 1909] (requesting) Query: 'site:linkedin.com/in  9Cookies Marcus Ross'
#   → Found: 'https://de.linkedin.com/in/rossmarcus'
# [Row 1910] (requesting) Query: 'site:linkedin.com/in  Hellocare Sergiej Rewiakin'
#   → Found: 'https://www.linkedin.com/in/antonnaumenko'
# [Row 1911] (requesting) Query: 'site:linkedin.com/in  mixd.tv Kristian Müller'
#   → Found: 'https://de.linkedin.com/in/kristian-m%C3%BCller-647245a'
# [Row 1912] (requesting) Query: 'site:linkedin.com/in  GLAMLOOP Alexandra Podeanu Zanders'
#   → Found: 'https://de.linkedin.com/in/alexandra-zanders'
# [Row 1913] (requesting) Query: 'site:linkedin.com/in  GLAMLOOP Kiana Mardi'
#   → Found: 'https://de.linkedin.com/in/kianamardi'
# [Row 1914] (requesting) Query: 'site:linkedin.com/in  GLAMLOOP Thomas Förster'
#   → No organic results; leaving as None
# [Row 1915] (requesting) Query: 'site:linkedin.com/in  Shoplove Hendrik Braun'
#   → No organic results; leaving as None
# [Row 1916] (requesting) Query: 'site:linkedin.com/in  Shoplove Timo Trumpp'
#   → No organic results; leaving as None
# [Row 1917] (requesting) Query: 'site:linkedin.com/in  Spotistic Danny Holtschke'
#   → No organic results; leaving as None
# [Row 1918] (requesting) Query: 'site:linkedin.com/in  Spotistic Maxence Decrosse'
#   → No organic results; leaving as None
# [Row 1919] (requesting) Query: 'site:linkedin.com/in  Spotistic Victor Landau'
#   → Found: 'https://de.linkedin.com/in/victorlandau'
# [Row 1920] (requesting) Query: 'site:linkedin.com/in  Transcatheter Technologies Hou-Sen Lim'
#   → Found: 'https://jp.linkedin.com/in/ayaka-ito-467a34aa/en'
# [Row 1921] (requesting) Query: 'site:linkedin.com/in  Transcatheter Technologies Wolfgang Goetz'
#   → Found: 'https://de.linkedin.com/in/wolfganggoetz'
# [Row 1922] (requesting) Query: 'site:linkedin.com/in  Toroleo Manuel Hinz'
#   → Found: 'https://de.linkedin.com/in/manuelhinz/de'
# [Row 1923] (requesting) Query: 'site:linkedin.com/in  Yoochoose Michael Friedmann'
#   → Found: 'https://www.linkedin.com/in/tsikinovsky'
# [Row 1924] (requesting) Query: 'site:linkedin.com/in  Yasuu Joern Dickhaut'
#   → No organic results; leaving as None
# [Row 1925] (requesting) Query: 'site:linkedin.com/in  Yasuu Oliver Nützel'
#   → Found: 'https://de.linkedin.com/in/olivernuetzel/de'
# [Row 1926] (requesting) Query: 'site:linkedin.com/in  p3dsystems Christian Hesse'
#   → No organic results; leaving as None
# [Row 1927] (requesting) Query: 'site:linkedin.com/in  p3dsystems Erwin A. Frei'
#   → No organic results; leaving as None
# [Row 1928] (requesting) Query: 'site:linkedin.com/in  stickapps Michael Gloess'
#   → No organic results; leaving as None
# [Row 1929] (requesting) Query: 'site:linkedin.com/in  Enshape Marcus Grober'
#   → No organic results; leaving as None
# [Row 1930] (requesting) Query: 'site:linkedin.com/in  Enshape Martin Schaffer'
#   → Found: 'https://de.linkedin.com/in/martin-schaffer-32b47a4a'
# [Row 1931] (requesting) Query: 'site:linkedin.com/in  disco volante Philipp Eibach'
#   → No organic results; leaving as None
# [Row 1932] (requesting) Query: 'site:linkedin.com/in  AutoDa Alexander Bugge'
#   → Found: 'https://no.linkedin.com/in/olga-budarina-968a8a72'
# [Row 1933] (requesting) Query: 'site:linkedin.com/in  Reputami GmbH Ali Saffari'
#   → Found: 'https://de.linkedin.com/in/oliverpitsch'
# [Row 1934] (requesting) Query: 'site:linkedin.com/in  Reputami GmbH Oliver Pitsch'
#   → Found: 'https://de.linkedin.com/in/oliverpitsch'
# [Row 1935] (requesting) Query: 'site:linkedin.com/in  RapidApe Daniel A. Garcia Rodriguez'
#   → No organic results; leaving as None
# [Row 1936] (requesting) Query: 'site:linkedin.com/in  RapidApe Sebastian Haas'
#   → No organic results; leaving as None
# [Row 1937] (requesting) Query: 'site:linkedin.com/in  defrac Joa Ebert'
#   → No organic results; leaving as None
# [Row 1938] (requesting) Query: 'site:linkedin.com/in  defrac Tim Richter'
#   → No organic results; leaving as None
# [Row 1939] (requesting) Query: 'site:linkedin.com/in  Medlanes Emil Kendziorra'
#   → Found: 'https://de.linkedin.com/in/emilkendziorra'
# [Row 1940] (requesting) Query: 'site:linkedin.com/in  Medlanes Erik Stoffregen'
#   → Found: 'https://de.linkedin.com/in/erikstoffregen'
# [Row 1941] (requesting) Query: 'site:linkedin.com/in  Gpredictive Björn Goerke'
#   → Found: 'https://de.linkedin.com/in/bgoerke'
# [Row 1942] (requesting) Query: 'site:linkedin.com/in  Gpredictive Dennis Proppe'
#   → No organic results; leaving as None
# [Row 1943] (requesting) Query: 'site:linkedin.com/in  Gpredictive Philippe Take'
#   → Found: 'https://de.linkedin.com/in/manuel-faza-9a294b63'
# [Row 1944] (requesting) Query: 'site:linkedin.com/in  Rebelle Cécile Wickmann'
#   → Found: 'https://de.linkedin.com/in/c%C3%A9cile-wickmann-a9360118'
# [Row 1945] (requesting) Query: 'site:linkedin.com/in  Rebelle Max Schönemann'
#   → Found: 'https://de.linkedin.com/in/max-sch%C3%B6nemann-140741129'
# [Row 1946] (requesting) Query: 'site:linkedin.com/in  GlamourRent Anna Ohlsen-Mangold'
#   → No organic results; leaving as None
# [Row 1947] (requesting) Query: 'site:linkedin.com/in  Kochzauber Frederic Knaudt'
#   → Found: 'https://de.linkedin.com/in/fredericknaudt'
# [Row 1948] (requesting) Query: 'site:linkedin.com/in  Kochzauber Wencke Harder'
#   → No organic results; leaving as None
# [Row 1949] (requesting) Query: 'site:linkedin.com/in  ARX Robotics Henrich Maximilian Wied'
#   → No organic results; leaving as None
# [Row 1950] (requesting) Query: 'site:linkedin.com/in  ARX Robotics Marc A Wietfeld'
#   → Found: 'https://de.linkedin.com/in/marc-a-wietfeld-b861a5204'
# [Row 1951] (requesting) Query: 'site:linkedin.com/in  ARX Robotics Stefan Roebel'
#   → Found: 'https://be.linkedin.com/in/samuel-jacquet-12b931309'
# [Row 1952] (requesting) Query: 'site:linkedin.com/in  1Komma5° Jannik Schall'
#   → Found: 'https://de.linkedin.com/in/jannik-schall'
# [Row 1953] (requesting) Query: 'site:linkedin.com/in  1Komma5° Micha Grueber'
#   → Found: 'https://de.linkedin.com/in/micha-grueber-10227814/en'
# [Row 1954] (requesting) Query: 'site:linkedin.com/in  1Komma5° Michael Hinderer'
#   → Found: 'https://de.linkedin.com/in/michael-hinderer-1048b3144'
# [Row 1955] (requesting) Query: 'site:linkedin.com/in  1Komma5° Philip Liesenfeld'
#   → Found: 'https://de.linkedin.com/in/philip-liesenfeld-a31851180'
# [Row 1956] (requesting) Query: 'site:linkedin.com/in  1Komma5° Philipp Schröder'
#   → Found: 'https://de.linkedin.com/in/philipp-schr%C3%B6der-b94b6576'
# [Row 1957] (requesting) Query: 'site:linkedin.com/in  ATMOS Space Cargo Christian Grimm'
#   → Found: 'https://de.linkedin.com/in/cdgrimm'
# [Row 1958] (requesting) Query: 'site:linkedin.com/in  ATMOS Space Cargo Jeffrey Hendrikse'
#   → Found: 'https://de.linkedin.com/in/jeffreyhendrikse'
# [Row 1959] (requesting) Query: 'site:linkedin.com/in  ATMOS Space Cargo Marta Oliveira'
#   → Found: 'https://de.linkedin.com/in/marta-oliveira-0468a3a0'
# [Row 1960] (requesting) Query: 'site:linkedin.com/in  ATMOS Space Cargo Sebastian Klaus'
#   → Found: 'https://www.linkedin.com/in/sebastian-klaus-b7676853/'
# [Row 1961] (requesting) Query: 'site:linkedin.com/in  Circus Group Carsten Wille'
#   → Found: 'https://de.linkedin.com/in/carsten-wille-11310a116'
# [Row 1962] (requesting) Query: 'site:linkedin.com/in  Circus Group Helge Plehn'
#   → Found: 'https://de.linkedin.com/in/helge-plehn'
# [Row 1963] (requesting) Query: 'site:linkedin.com/in  Circus Group Nikolas Bullwinkel'
#   → Found: 'https://de.linkedin.com/in/nikolasbullwinkel/en'
# [Row 1964] (requesting) Query: 'site:linkedin.com/in  Ivy Ferdinand Dabitz'
#   → Found: 'https://de.linkedin.com/in/ferdinand-dabitz'
# [Row 1965] (requesting) Query: 'site:linkedin.com/in  Payrails Emre Talay'
#   → Found: 'https://de.linkedin.com/in/emre-talay'
# [Row 1966] (requesting) Query: 'site:linkedin.com/in  Payrails Orkhan Abdullayev'
#   → Found: 'https://de.linkedin.com/in/orkhanab'
# [Row 1967] (requesting) Query: 'site:linkedin.com/in  Mondu Gil Danziger'
#   → Found: 'https://il.linkedin.com/in/eliezer-danziger-7789b036'
# [Row 1968] (requesting) Query: 'site:linkedin.com/in  Mondu Malte Huffmann'
#   → Found: 'https://de.linkedin.com/in/malte-huffmann-1771b528'
# [Row 1969] (requesting) Query: 'site:linkedin.com/in  Mondu Nadia Kroon'
#   → Found: 'https://it.linkedin.com/in/graziella-pica/it?trk=public_post_comment_actor-image'
# [Row 1970] (requesting) Query: 'site:linkedin.com/in  Mondu Philipp Povel'
#   → Found: 'https://de.linkedin.com/in/philipp-povel-9a309718'
# [Row 1971] (requesting) Query: 'site:linkedin.com/in  Doinstruct Mona Feder'
#   → Found: 'https://de.linkedin.com/in/monafeder'
# [Row 1972] (requesting) Query: 'site:linkedin.com/in  The Exploration Company Artur Koop'
#   → Found: 'https://de.linkedin.com/in/arturkoop'
# [Row 1973] (requesting) Query: 'site:linkedin.com/in  The Exploration Company Hélène Huby'
#   → Found: 'https://de.linkedin.com/in/helenehuby'
# [Row 1974] (requesting) Query: 'site:linkedin.com/in  The Exploration Company Jon Reijneveld'
#   → Found: 'https://fr.linkedin.com/in/jonreijneveld'
# [Row 1975] (requesting) Query: 'site:linkedin.com/in  Planet A Foods Dr. Maximilian Marquart'
#   → Found: 'https://de.linkedin.com/in/dr-maximilian-marquart-24a802107'
# [Row 1976] (requesting) Query: 'site:linkedin.com/in  Planet A Foods Sara F. Marquart'
#   → Found: 'https://de.linkedin.com/in/saramarquart'
# [Row 1977] (requesting) Query: 'site:linkedin.com/in  C1 Green Chemicals Christian Vollmann'
#   → Found: 'https://de.linkedin.com/in/christianvollmann'
# [Row 1978] (requesting) Query: 'site:linkedin.com/in  C1 Green Chemicals Marek Checinski'
#   → Found: 'https://de.linkedin.com/in/marek-checinski'
# [Row 1979] (requesting) Query: 'site:linkedin.com/in  Reverion Felix Fischer'
#   → Found: 'https://de.linkedin.com/in/fefischer'
# [Row 1980] (requesting) Query: 'site:linkedin.com/in  Reverion Jeremias Weinrich'
#   → Found: 'https://de.linkedin.com/in/jeremias-weinrich-14a053217'
# [Row 1981] (requesting) Query: 'site:linkedin.com/in  Reverion Luis Poblotzki'
#   → Found: 'https://de.linkedin.com/in/poblotzki'
# [Row 1982] (requesting) Query: 'site:linkedin.com/in  Reverion Maximilian Hauck'
#   → Found: 'https://de.linkedin.com/in/maximilian-hauck-877a45155'
# [Row 1983] (requesting) Query: 'site:linkedin.com/in  Reverion Stephan Herrmann'
#   → Found: 'https://de.linkedin.com/in/stephan-herrmann-b76338217'
# [Row 1984] (requesting) Query: 'site:linkedin.com/in  Sereact Marc Tuscher'
#   → Found: 'https://de.linkedin.com/in/marc-tuscher-3b4048149'
# [Row 1985] (requesting) Query: 'site:linkedin.com/in  Sereact Ralf Gulde'
#   → Found: 'https://de.linkedin.com/in/ralf-gulde'
# [Row 1986] (requesting) Query: 'site:linkedin.com/in  carbmee GmbH Christian Heinrich'
#   → Found: 'https://de.linkedin.com/in/prof-christian-heinrich-79ab3437/en'
# [Row 1987] (requesting) Query: 'site:linkedin.com/in  carbmee GmbH Hendrik Beneke'
#   → No organic results; leaving as None
# [Row 1988] (requesting) Query: 'site:linkedin.com/in  carbmee GmbH Robin Spickers'
#   → Found: 'https://de.linkedin.com/in/robinspickers'
# [Row 1989] (requesting) Query: 'site:linkedin.com/in  bunch Enrico Ohnemueller'
#   → Found: 'https://de.linkedin.com/in/enrico-ohnem%C3%BCller-321459119'
# [Row 1990] (requesting) Query: 'site:linkedin.com/in  bunch Levent Altunel'
#   → Found: 'https://de.linkedin.com/in/levent-altunel'
# [Row 1991] (requesting) Query: 'site:linkedin.com/in  Predium Maximilian Korner'
#   → Found: 'https://de.linkedin.com/in/maximilian-k%C3%B6rner-70b479b6'
# [Row 1992] (requesting) Query: 'site:linkedin.com/in  planqc Alexander Glätzle Ph.D'
#   → Found: 'https://de.linkedin.com/in/glaetzle'
# [Row 1993] (requesting) Query: 'site:linkedin.com/in  planqc Ann-Kristin Achleitner'
#   → No organic results; leaving as None
# [Row 1994] (requesting) Query: 'site:linkedin.com/in  planqc Johannes Zeiher Ph.D'
#   → Found: 'https://de.linkedin.com/in/johannes-zeiher-64b594168'
# [Row 1995] (requesting) Query: 'site:linkedin.com/in  planqc Lukas Reichsöllner Ph.D'
#   → Found: 'https://de.linkedin.com/in/lukas-reichsoellner-648297145'
# [Row 1996] (requesting) Query: 'site:linkedin.com/in  planqc Markus Wagner'
#   → Found: 'https://www.linkedin.com/in/wagnermarkus'
# [Row 1997] (requesting) Query: 'site:linkedin.com/in  planqc Sebastian Blatt Ph.D'
#   → Found: 'https://de.linkedin.com/in/sebastian-blatt'
# [Row 1998] (requesting) Query: 'site:linkedin.com/in  LANCH Dominic Kluge'
#   → Found: 'https://de.linkedin.com/in/dominic-kluge-335649127'
# [Row 1999] (requesting) Query: 'site:linkedin.com/in  LANCH Jonas Meynert'
#   → Found: 'https://de.linkedin.com/in/jonas-meynert'
